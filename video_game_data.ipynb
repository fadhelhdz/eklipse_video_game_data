# %%
import pandas as pd
from google import genai
import re
from dotenv import load_dotenv
import os

# %%
df = pd.read_csv('Game Thumbnail.csv')
api_key = os.getenv("GOOGLE_API_KEY")

# %%
# df = df.head(5)
df.shape
# Out:
# (50, 2)

# %%
def genre_classifier(titles, client=None, batch_size=5):
    """
    Classifies multiple video game titles into genres and returns results ready for DataFrame.
    
    Args:
        titles (list or pandas.Series): List or Series of video game titles to classify
        client (genai.Client, optional): The Gemini API client. If None, uses the global client.
        batch_size (int): Number of titles to process in each batch
        
    Returns:
        list: List of genre classifications corresponding to input titles
    """
    # Use provided client or fall back to global client
    if client is None:
        from google import genai
        client_to_use = genai.Client(api_key=api_key)
    else:
        client_to_use = client
    
    # Convert to list if it's a pandas Series
    if hasattr(titles, 'tolist'):
        titles = titles.tolist()
    
    results = []
    
    # Process in batches to avoid API rate limits
    for i in range(0, len(titles), batch_size):
        batch = titles[i:i+batch_size]
        
        # Create a prompt that handles multiple titles at once
        prompt = "Classify each of the following video games into a single-word genre category. For each game, respond with ONLY the genre name, one per line, in the same order as the games listed:\n\n"
        for title in batch:
            prompt += f"- {title}\n"
        
        response = client_to_use.models.generate_content(
            model='gemini-2.0-flash-lite',
            contents=prompt
        )
        
        # Parse the response - expecting one genre per line
        genres = response.text.strip().split('\n')
        # Clean up any bullet points or numbering
        genres = [g.strip().lstrip('-').lstrip('*').lstrip('1234567890.').strip() for g in genres]
        
        # Only take as many results as we had titles
        results.extend(genres[:len(batch)])
    
    return results

df['genre'] = genre_classifier(df['game_title'])

# %%
df.head()
# Out:
#             game_title                                          image_url  \
# 0     Street Fighter 6  https://images.igdb.com/igdb/image/upload/t_co...
# 1  Hunt: Showdown 1896  https://images.igdb.com/igdb/image/upload/t_co...
# 2      Wuthering Waves  https://images.igdb.com/igdb/image/upload/t_co...
# 3        Arma Reforger  https://images.igdb.com/igdb/image/upload/t_co...
# 4       Lethal Company  https://images.igdb.com/igdb/image/upload/t_co...
#
#       genre
# 0  Fighting
# 1  Survival
# 2    Action
# 3  Tactical
# 4  Survival

# %%
def gen_short_desc(titles, client=None, batch_size=5):
    """
    Generates a short description for a video game using the given title.
    Args:
        titles (list or pandas.Series): List or Series of video game titles to classify
        client (genai.Client, optional): The Gemini API client. If None, uses the global client.
        batch_size (int): Number of titles to process in each batch
        
    Returns:
        list: List of short descriptions corresponding to input titles
    """
    # Use provided client or fall back to global client
    if client is None:
        from google import genai
        client_to_use = genai.Client(api_key=api_key)
    else:
        client_to_use = client
    
    # Convert to list if it's a pandas Series
    if hasattr(titles, 'tolist'):
        titles = titles.tolist()
    
    results = []
    
    # Process in batches to avoid API rate limits
    for i in range(0, len(titles), batch_size):
        batch = titles[i:i+batch_size]
        
        # Create a prompt that handles multiple titles at once
        prompt = "Generate short descriptions for each of the following video games. For each game, respond with ONLY the short description under 30 words, each in one line, in the same order as the games listed:\n\n"
        for title in batch:
            prompt += f"- {title}\n"
        
        response = client_to_use.models.generate_content(
            model='gemini-2.0-flash-lite',
            contents=prompt
        )
        
        # Parse the response - expecting one genre per line
        descriptions = response.text.strip().split('\n')
        # Clean up any bullet points or numbering
        descriptions = [d.strip().lstrip('-').lstrip('*') for d in descriptions]
        descriptions = [re.sub(r'^(\d+)[\.\)]?\s*', '', d).strip() for d in descriptions]
        
        # Only take as many results as we had titles
        results.extend(descriptions[:len(batch)])

    print(results)
    return results

df['short_description'] = gen_short_desc(df['game_title'])
# Out:
# ['Street Fighter 6:', 'Next-gen fighting with diverse characters, engaging modes, and a modern, accessible experience.', '', 'Hunt: Showdown 1896:', 'Brutal PvPvE bounty hunting in a gothic, atmospheric Louisiana swamp. Fight monsters and players for glory.', 'Arena Breakout: Infinite: A tactical extraction FPS where you raid warzones, loot valuable gear, and fight to survive.', 'Zenless Zone Zero: A stylish action RPG set in a post-apocalyptic city, battling monsters with unique characters.', 'ARK: Survival Ascended: Survive a prehistoric, hostile island filled with dinosaurs, craft, build, and tame creatures.', "Sid Meier's Civilization VII: Build an empire to stand the test of time, make pivotal decisions to expand your empire.", 'SMITE 2: A revamped MOBA featuring gods battling for dominance, with updated visuals and gameplay.', 'A free-to-play MMORPG with dynamic combat, world transformation, and seamless transitions between areas.', 'Survive and build in a vast, voxel-based open world, battling enemies and uncovering secrets.', 'Survive the horrors within Playtime Co., solving puzzles and avoiding terrifying toys.', 'A co-op adventure where two players must work together to overcome challenges and save their marriage.', 'Experience epic, one-versus-thousand battles across ancient China, with new evolved combat and open world.', 'Skate, shoot, and brawl your way to the Stanley Cup in this fast-paced hockey simulation.', 'A deck-building roguelike where you bluff your way to the top by playing poker hands.', 'Explore an adorable 3D world, make friends, and solve puzzles in this cozy adventure game.', 'Embark on a journey of self-discovery and destiny as you fight to save the world from chaos.', 'Journey around the globe as the iconic archaeologist in a thrilling first-person adventure.', 'Hell Let Loose: A brutal WWII first-person shooter emphasizing teamwork and historical accuracy in large-scale battles.', "Super Mario 64: Mario's iconic 3D debut! Explore vibrant worlds, collect stars, and rescue Princess Peach from Bowser.", 'S.T.A.L.K.E.R. 2: Heart of Chornobyl: Survive the irradiated Zone. Explore, scavenge, and fight for survival in this post-apocalyptic FPS.', 'STALCRAFT: X: A gritty MMO set in the Zone. Scavenge, explore, and fight for resources in a harsh post-apocalyptic world.', "Supermarket Together: Coop supermarket simulator. Manage your store's inventory, serve customers, and avoid financial ruin.", 'Here are the short descriptions:', '', 'Ragnarok Online 2: A vibrant MMORPG with colorful graphics, offering diverse classes, epic quests, and a focus on social interaction.', '', 'The Outlast Trials: Survive psychological horrors and gruesome trials solo or with friends in this terrifying prequel.', "Survive the Amazon rainforest's perils in this realistic survival simulator, battling hunger, injury, and madness.", 'Experience the vast skies in this detailed flight simulator, exploring diverse locations and aircraft.', 'Assemble a team of champions, strategize, and outplay opponents in this auto-battler.', 'Explore an infinite procedurally generated universe filled with planets, creatures, and space battles.', 'Cultivate your farm, manage resources, and experience the joys of rural life with new features.', 'Fight to save a collapsing Washington D.C. in this open-world looter shooter, battling factions for control.', 'Smash Bros. Ultimate brings together iconic gaming characters for chaotic, platform-fighting action.', 'Survive as a zombie apocalypse rages on, parkouring through a city to scavenge and fight.', 'Use stealth and sniping to eliminate Nazi targets in World War II, with brutal X-ray kill cams.', 'Explore a new world with MMO features. Conquer resources and battle threats with others.', 'Hello Kitty Island Adventure:', 'Explore a vibrant island, befriend characters, and build your dream getaway with beloved Sanrio friends!', '', 'The Headliners:', 'Manage a newspaper, make ethical choices, and naviga ...

# %%
df
# Out:
#                               game_title  \
# 0                       Street Fighter 6
# 1                    Hunt: Showdown 1896
# 2                        Wuthering Waves
# 3                          Arma Reforger
# 4                         Lethal Company
# 5               Arena Breakout: Infinite
# 6                      Zenless Zone Zero
# 7                 ARK: Survival Ascended
# 8           Sid Meier's Civilization VII
# 9                                SMITE 2
# 10                    Throne and Liberty
# 11                            Enshrouded
# 12                        Poppy Playtime
# 13                          It Takes Two
# 14             DYNASTY WARRIORS: ORIGINS
# 15                                NHL 25
# 16                               Balatro
# 17                                MiSide
# 18                  Metaphor: ReFantazio
# 19    Indiana Jones and the Great Circle
# 20                        Hell Let Loose
# 21                        Super Mario 64
# 22  S.T.A.L.K.E.R. 2: Heart of Chornobyl
# 23                          STALCRAFT: X
# 24                  Supermarket Together
# 25                     Ragnarok Online 2
# 26                    The Outlast Trials
# 27                 Detroit: Become Human
# 28                       EA Sports UFC 2
# 29                                 Palia
# 30                            Green Hell
# 31       Microsoft Flight Simulator 2024
# 32                     Teamfight Tactics
# 33                          No Man's Sky
# 34                  Farming Simulator 25
# 35           Tom Clancy's The Division 2
# 36            Super Smash Bros. Ultimate
# 37                           Dying Light
# 38              Sniper Elite: Resistance
# 39                   New World: Aeternum
# 40          Hello Kitty Island Adventure
# 41                        The Headliners
# 42                            Mir Tankov
# 43      The Binding of Isaac: Repentance
# 44                              Exoborne
# 45         Grand Theft Auto: San Andreas
# 46                        Infinity Nikki
# 47                         Borderlands 3
# 48                         Knight Online
# 49                 Supermarket Simulator
#
#                                             image_url        genre  \
# 0   https://images.igdb.com/igdb/image/upload/t_co...     Fighting
# 1   https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 2   https://images.igdb.com/igdb/image/upload/t_co...       Action
# 3   https://images.igdb.com/igdb/image/upload/t_co...     Tactical
# 4   https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 5   https://images.igdb.com/igdb/image/upload/t_co...      Shooter
# 6   https://images.igdb.com/igdb/image/upload/t_co...          RPG
# 7   https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 8   https://images.igdb.com/igdb/image/upload/t_co...     Strategy
# 9   https://images.igdb.com/igdb/image/upload/t_co...         MOBA
# 10  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 11  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 12  https://images.igdb.com/igdb/image/upload/t_co...       Horror
# 13  https://images.igdb.com/igdb/image/upload/t_co...   Platformer
# 14  https://images.igdb.com/igdb/image/upload/t_co...       Action
# 15  https://images.igdb.com/igdb/image/upload/t_co...       Sports
# 16  https://images.igdb.com/igdb/image/upload/t_co...  Deckbuilder
# 17  https://images.igdb.com/igdb/image/upload/t_co...       Rhythm
# 18  https://images.igdb.com/igdb/image/upload/t_co...          RPG
# 19  https://images.igdb.com/igdb/image/upload/t_co...    Adventure
# 20  https://images.igdb.com/igdb/image/upload/t_co...      Shooter
# 21  https://images.igdb.com/igdb/image/upload/t_co...   Platformer
# 22  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 23  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 24  https://images.igdb.com/igdb/image/upload/t_co...   Simulation
# 25  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 26  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 27  https://images.igdb.com/igdb/image/upload/t_co...    Adventure
# 28  https://images.igdb.com/igdb/image/upload/t_co...     Fighting
# 29  https://images.igdb.com/igdb/image/upload/t_co...         Cozy
# 30  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 31  https://images.igdb.com/igdb/image/upload/t_co...    Simulator
# 32  https://images.igdb.com/igdb/image/upload/t_co...  Autobattler
# 33  https://images.igdb.com/igdb/image/upload/t_co...      Sandbox
# 34  https://images.igdb.com/igdb/image/upload/t_co...   Simulation
# 35  https://images.igdb.com/igdb/image/upload/t_co...       Action
# 36  https://images.igdb.com/igdb/image/upload/t_co...     Fighting
# 37  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 38  https://images.igdb.com/igdb/image/upload/t_co...     Tactical
# 39  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 40  https://images.igdb.com/igdb/image/upload/t_co...    Adventure
# 41  https://images.igdb.com/igdb/image/upload/t_co...       Puzzle
# 42  https://images.igdb.com/igdb/image/upload/t_co...   Simulation
# 43  https://images.igdb.com/igdb/image/upload/t_co...    Roguelike
# 44  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 45  https://images.igdb.com/igdb/image/upload/t_co...       Action
# 46  https://images.igdb.com/igdb/image/upload/t_co...          RPG
# 47  https://images.igdb.com/igdb/image/upload/t_co...      Shooter
# 48  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 49  https://images.igdb.com/igdb/image/upload/t_co...   Simulation
#
#                                     short_description
# 0                                   Street Fighter 6:
# 1   Next-gen fighting with diverse characters, eng...
# 2
# 3                                Hunt: Showdown 1896:
# 4   Brutal PvPvE bounty hunting in a gothic, atmos...
# 5   Arena Breakout: Infinite: A tactical extractio...
# 6   Zenless Zone Zero: A stylish action RPG set in...
# 7   ARK: Survival Ascended: Survive a prehistoric,...
# 8   Sid Meier's Civilization VII: Build an empire ...
# 9   SMITE 2: A revamped MOBA featuring gods battli...
# 10  A free-to-play MMORPG with dynamic combat, wor...
# 11  Survive and build in a vast, voxel-based open ...
# 12  Survive the horrors within Playtime Co., solvi...
# 13  A co-op adventure where two players must work ...
# 14  Experience epic, one-versus-thousand battles a...
# 15  Skate, shoot, and brawl your way to the Stanle...
# 16  A deck-building roguelike where you bluff your...
# 17  Explore an adorable 3D world, make friends, an...
# 18  Embark on a journey of self-discovery and dest...
# 19  Journey around the globe as the iconic archaeo...
# 20  Hell Let Loose: A brutal WWII first-person sho...
# 21  Super Mario 64: Mario's iconic 3D debut! Explo...
# 22  S.T.A.L.K.E.R. 2: Heart of Chornobyl: Survive ...
# 23  STALCRAFT: X: A gritty MMO set in the Zone. Sc...
# 24  Supermarket Together: Coop supermarket simulat...
# 25                   Here are the short descriptions:
# 26
# 27  Ragnarok Online 2: A vibrant MMORPG with color...
# 28
# 29  The Outlast Trials: Survive psychological horr...
# 30  Survive the Amazon rainforest's perils in this...
# 31  Experience the vast skies in this detailed fli...
# 32  Assemble a team of champions, strategize, and ...
# 33  Explore an infinite procedurally generated uni...
# 34  Cultivate your farm, manage resources, and exp...
# 35  Fight to save a collapsing Washington D.C. in ...
# 36  Smash Bros. Ultimate brings together iconic ga...
# 37  Survive as a zombie apocalypse rages on, parko...
# 38  Use stealth and sniping to eliminate Nazi targ...
# 39  Explore a new world with MMO features. Conquer...
# 40                      Hello Kitty Island Adventure:
# 41  Explore a vibrant island, befriend characters,...
# 42
# 43                                    The Headliners:
# 44  Manage a newspaper, make ethical choices, and ...
# 45                   Here are the short descriptions:
# 46
# 47  Explore the vast open world of San Andreas, bu...
# 48
# 49  Dress up Nikki, style her in stunning outfits,...

# %%
df['short_description']
# Out:
# 0                                     Street Fighter 6:
# 1     Next-gen fighting with diverse characters, eng...
# 2
# 3                                  Hunt: Showdown 1896:
# 4     Brutal PvPvE bounty hunting in a gothic, atmos...
# 5     Arena Breakout: Infinite: A tactical extractio...
# 6     Zenless Zone Zero: A stylish action RPG set in...
# 7     ARK: Survival Ascended: Survive a prehistoric,...
# 8     Sid Meier's Civilization VII: Build an empire ...
# 9     SMITE 2: A revamped MOBA featuring gods battli...
# 10    A free-to-play MMORPG with dynamic combat, wor...
# 11    Survive and build in a vast, voxel-based open ...
# 12    Survive the horrors within Playtime Co., solvi...
# 13    A co-op adventure where two players must work ...
# 14    Experience epic, one-versus-thousand battles a...
# 15    Skate, shoot, and brawl your way to the Stanle...
# 16    A deck-building roguelike where you bluff your...
# 17    Explore an adorable 3D world, make friends, an...
# 18    Embark on a journey of self-discovery and dest...
# 19    Journey around the globe as the iconic archaeo...
# 20    Hell Let Loose: A brutal WWII first-person sho...
# 21    Super Mario 64: Mario's iconic 3D debut! Explo...
# 22    S.T.A.L.K.E.R. 2: Heart of Chornobyl: Survive ...
# 23    STALCRAFT: X: A gritty MMO set in the Zone. Sc...
# 24    Supermarket Together: Coop supermarket simulat...
# 25                     Here are the short descriptions:
# 26
# 27    Ragnarok Online 2: A vibrant MMORPG with color...
# 28
# 29    The Outlast Trials: Survive psychological horr...
# 30    Survive the Amazon rainforest's perils in this...
# 31    Experience the vast skies in this detailed fli...
# 32    Assemble a team of champions, strategize, and ...
# 33    Explore an infinite procedurally generated uni...
# 34    Cultivate your farm, manage resources, and exp...
# 35    Fight to save a collapsing Washington D.C. in ...
# 36    Smash Bros. Ultimate brings together iconic ga...
# 37    Survive as a zombie apocalypse rages on, parko...
# 38    Use stealth and sniping to eliminate Nazi targ...
# 39    Explore a new world with MMO features. Conquer...
# 40                        Hello Kitty Island Adventure:
# 41    Explore a vibrant island, befriend characters,...
# 42
# 43                                      The Headliners:
# 44    Manage a newspaper, make ethical choices, and ...
# 45                     Here are the short descriptions:
# 46
# 47    Explore the vast open world of San Andreas, bu...
# 48
# 49    Dress up Nikki, style her in stunning outfits,...
# Name: short_description, dtype: object

# %%
def player_mode_classifier(titles, client=None, batch_size=5):
    """
    Classifies the player mode of multiple video game titles.
    
    Args:
        titles (list or pandas.Series): List or Series of video game titles to classify
        client (genai.Client, optional): The Gemini API client. If None, uses the global client.
        batch_size (int): Number of titles to process in each batch
        
    Returns:
        list: List of player mode classifications corresponding to input titles
    """
    # Use provided client or fall back to global client
    if client is None:
        from google import genai
        client_to_use = genai.Client(api_key="api_key")
    else:
        client_to_use = client
    
    # Convert to list if it's a pandas Series
    if hasattr(titles, 'tolist'):
        titles = titles.tolist()
    
    results = []
    
    # Process in batches to avoid API rate limits
    for i in range(0, len(titles), batch_size):
        batch = titles[i:i+batch_size]
        
        # Create a prompt that handles multiple titles at once
        prompt = "Classify each of the following video games based on their player mode. For each game, respond with ONLY one of these three options: 'Singleplayer', 'Multiplayer', or 'Both'. A game should be classified as 'Both' if it includes any cooperative or online multiplayer features, even if primarily designed for single-player. Respond with one classification per line, in the same order as the games listed:\n\n"
        for title in batch:
            prompt += f"- {title}\n"
        
        response = client_to_use.models.generate_content(
            model='gemini-2.0-flash-lite',
            contents=prompt
        )
        
        # Parse the response - expecting one genre per line
        player_mode = response.text.strip().split('\n')
        # Clean up any bullet points or numbering
        player_mode = [p.strip().lstrip('-').lstrip('*').lstrip('1234567890.').strip() for p in player_mode]
        
        # Only take as many results as we had titles
        results.extend(player_mode[:len(batch)])
    
    return results

df['player_mode'] = player_mode_classifier(df['game_title'])

# %%
df
# Out:
#                               game_title  \
# 0                       Street Fighter 6
# 1                    Hunt: Showdown 1896
# 2                        Wuthering Waves
# 3                          Arma Reforger
# 4                         Lethal Company
# 5               Arena Breakout: Infinite
# 6                      Zenless Zone Zero
# 7                 ARK: Survival Ascended
# 8           Sid Meier's Civilization VII
# 9                                SMITE 2
# 10                    Throne and Liberty
# 11                            Enshrouded
# 12                        Poppy Playtime
# 13                          It Takes Two
# 14             DYNASTY WARRIORS: ORIGINS
# 15                                NHL 25
# 16                               Balatro
# 17                                MiSide
# 18                  Metaphor: ReFantazio
# 19    Indiana Jones and the Great Circle
# 20                        Hell Let Loose
# 21                        Super Mario 64
# 22  S.T.A.L.K.E.R. 2: Heart of Chornobyl
# 23                          STALCRAFT: X
# 24                  Supermarket Together
# 25                     Ragnarok Online 2
# 26                    The Outlast Trials
# 27                 Detroit: Become Human
# 28                       EA Sports UFC 2
# 29                                 Palia
# 30                            Green Hell
# 31       Microsoft Flight Simulator 2024
# 32                     Teamfight Tactics
# 33                          No Man's Sky
# 34                  Farming Simulator 25
# 35           Tom Clancy's The Division 2
# 36            Super Smash Bros. Ultimate
# 37                           Dying Light
# 38              Sniper Elite: Resistance
# 39                   New World: Aeternum
# 40          Hello Kitty Island Adventure
# 41                        The Headliners
# 42                            Mir Tankov
# 43      The Binding of Isaac: Repentance
# 44                              Exoborne
# 45         Grand Theft Auto: San Andreas
# 46                        Infinity Nikki
# 47                         Borderlands 3
# 48                         Knight Online
# 49                 Supermarket Simulator
#
#                                             image_url        genre  \
# 0   https://images.igdb.com/igdb/image/upload/t_co...     Fighting
# 1   https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 2   https://images.igdb.com/igdb/image/upload/t_co...       Action
# 3   https://images.igdb.com/igdb/image/upload/t_co...     Tactical
# 4   https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 5   https://images.igdb.com/igdb/image/upload/t_co...      Shooter
# 6   https://images.igdb.com/igdb/image/upload/t_co...          RPG
# 7   https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 8   https://images.igdb.com/igdb/image/upload/t_co...     Strategy
# 9   https://images.igdb.com/igdb/image/upload/t_co...         MOBA
# 10  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 11  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 12  https://images.igdb.com/igdb/image/upload/t_co...       Horror
# 13  https://images.igdb.com/igdb/image/upload/t_co...   Platformer
# 14  https://images.igdb.com/igdb/image/upload/t_co...       Action
# 15  https://images.igdb.com/igdb/image/upload/t_co...       Sports
# 16  https://images.igdb.com/igdb/image/upload/t_co...  Deckbuilder
# 17  https://images.igdb.com/igdb/image/upload/t_co...       Rhythm
# 18  https://images.igdb.com/igdb/image/upload/t_co...          RPG
# 19  https://images.igdb.com/igdb/image/upload/t_co...    Adventure
# 20  https://images.igdb.com/igdb/image/upload/t_co...      Shooter
# 21  https://images.igdb.com/igdb/image/upload/t_co...   Platformer
# 22  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 23  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 24  https://images.igdb.com/igdb/image/upload/t_co...   Simulation
# 25  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 26  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 27  https://images.igdb.com/igdb/image/upload/t_co...    Adventure
# 28  https://images.igdb.com/igdb/image/upload/t_co...     Fighting
# 29  https://images.igdb.com/igdb/image/upload/t_co...         Cozy
# 30  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 31  https://images.igdb.com/igdb/image/upload/t_co...    Simulator
# 32  https://images.igdb.com/igdb/image/upload/t_co...  Autobattler
# 33  https://images.igdb.com/igdb/image/upload/t_co...      Sandbox
# 34  https://images.igdb.com/igdb/image/upload/t_co...   Simulation
# 35  https://images.igdb.com/igdb/image/upload/t_co...       Action
# 36  https://images.igdb.com/igdb/image/upload/t_co...     Fighting
# 37  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 38  https://images.igdb.com/igdb/image/upload/t_co...     Tactical
# 39  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 40  https://images.igdb.com/igdb/image/upload/t_co...    Adventure
# 41  https://images.igdb.com/igdb/image/upload/t_co...       Puzzle
# 42  https://images.igdb.com/igdb/image/upload/t_co...   Simulation
# 43  https://images.igdb.com/igdb/image/upload/t_co...    Roguelike
# 44  https://images.igdb.com/igdb/image/upload/t_co...     Survival
# 45  https://images.igdb.com/igdb/image/upload/t_co...       Action
# 46  https://images.igdb.com/igdb/image/upload/t_co...          RPG
# 47  https://images.igdb.com/igdb/image/upload/t_co...      Shooter
# 48  https://images.igdb.com/igdb/image/upload/t_co...       MMORPG
# 49  https://images.igdb.com/igdb/image/upload/t_co...   Simulation
#
#                                     short_description   player_mode
# 0                                   Street Fighter 6:   Multiplayer
# 1   Next-gen fighting with diverse characters, eng...   Multiplayer
# 2                                                              Both
# 3                                Hunt: Showdown 1896:   Multiplayer
# 4   Brutal PvPvE bounty hunting in a gothic, atmos...   Multiplayer
# 5   Arena Breakout: Infinite: A tactical extractio...   Multiplayer
# 6   Zenless Zone Zero: A stylish action RPG set in...          Both
# 7   ARK: Survival Ascended: Survive a prehistoric,...          Both
# 8   Sid Meier's Civilization VII: Build an empire ...  Singleplayer
# 9   SMITE 2: A revamped MOBA featuring gods battli...   Multiplayer
# 10  A free-to-play MMORPG with dynamic combat, wor...   Multiplayer
# 11  Survive and build in a vast, voxel-based open ...          Both
# 12  Survive the horrors within Playtime Co., solvi...          Both
# 13  A co-op adventure where two players must work ...          Both
# 14  Experience epic, one-versus-thousand battles a...   Multiplayer
# 15  Skate, shoot, and brawl your way to the Stanle...   Multiplayer
# 16  A deck-building roguelike where you bluff your...  Singleplayer
# 17  Explore an adorable 3D world, make friends, an...  Singleplayer
# 18  Embark on a journey of self-discovery and dest...  Singleplayer
# 19  Journey around the globe as the iconic archaeo...  Singleplayer
# 20  Hell Let Loose: A brutal WWII first-person sho...   Multiplayer
# 21  Super Mario 64: Mario's iconic 3D debut! Explo...  Singleplayer
# 22  S.T.A.L.K.E.R. 2: Heart of Chornobyl: Survive ...          Both
# 23  STALCRAFT: X: A gritty MMO set in the Zone. Sc...          Both
# 24  Supermarket Together: Coop supermarket simulat...          Both
# 25                   Here are the short descriptions:   Multiplayer
# 26                                                             Both
# 27  Ragnarok Online 2: A vibrant MMORPG with color...  Singleplayer
# 28                                                      Multiplayer
# 29  The Outlast Trials: Survive psychological horr...          Both
# 30  Survive the Amazon rainforest's perils in this...          Both
# 31  Experience the vast skies in this detailed fli...          Both
# 32  Assemble a team of champions, strategize, and ...   Multiplayer
# 33  Explore an infinite procedurally generated uni...          Both
# 34  Cultivate your farm, manage resources, and exp...   Multiplayer
# 35  Fight to save a collapsing Washington D.C. in ...          Both
# 36  Smash Bros. Ultimate brings together iconic ga...   Multiplayer
# 37  Survive as a zombie apocalypse rages on, parko...          Both
# 38  Use stealth and sniping to eliminate Nazi targ...  Singleplayer
# 39  Explore a new world with MMO features. Conquer...   Multiplayer
# 40                      Hello Kitty Island Adventure:          Both
# 41  Explore a vibrant island, befriend characters,...   Multiplayer
# 42                                                      Multiplayer
# 43                                    The Headliners:          Both
# 44  Manage a newspaper, make ethical choices, and ...   Multiplayer
# 45                   Here are the short descriptions:          Both
# 46                                                     Singleplayer
# 47  Explore the vast open world of San Andreas, bu...          Both
# 48                                                      Multiplayer
# 49  Dress up Nikki, style her in stunning outfits,...          Both
